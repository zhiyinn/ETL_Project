# %%
# Import dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import datetime
from datetime import date
from datetime import time
from datetime import datetime
#import calendar
import warnings
warnings.filterwarnings('ignore')
import io

# %%
# https://nikgrozev.com/2015/06/16/fast-and-simple-sampling-in-pandas-when-loading-data-from-files/
# Fast and Simple Sampling in Pandas when Loading Data From Files

import random
# The data to load
f = "Resources/LA_crime.csv"

# Count the lines
num_lines = sum(1 for l in open(f))

# Sample size - in this case ~10%
size = int(num_lines / 10)

# The row indices to skip - make sure 0 is not included to keep the header!
skip_idx = random.sample(range(1, num_lines), num_lines - size)

# Read the data
la_crime_df = pd.read_csv(f, skiprows=skip_idx)
la_crime_df.head(2)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191504131    01/03/2019    01/02/2018           2330       15  N Hollywood
# 1  190704048    01/02/2019    01/02/2018           1000        7     Wilshire
#
#    Reporting District  Crime Code  \
# 0                1535         420
# 1                 774         510
#
#                             Crime Code Description MO Codes  \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)     0344
# 1                                 VEHICLE - STOLEN      NaN
#
#            ...           Weapon Description Status Code Status Description  \
# 0          ...                          NaN          IC        Invest Cont
# 1          ...                          NaN          AA       Adult Arrest
#
#    Crime Code 1 Crime Code 2  Crime Code 3 Crime Code 4  \
# 0           420          NaN           NaN          NaN
# 1           510          NaN           NaN          NaN
#
#                                   Address Cross Street             Location
# 0                                 TUJUNGA     HATTERAS   (34.1758, -118.379)
# 1  400 S  CROCKER                      ST          NaN  (34.0431, -118.3482)
#
# [2 rows x 26 columns]

# %%
# Remove parantesis from Location column
la_crime_df['Location_clean']=la_crime_df['Location '].str.strip('()')
la_crime_df.head(2)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191504131    01/03/2019    01/02/2018           2330       15  N Hollywood
# 1  190704048    01/02/2019    01/02/2018           1000        7     Wilshire
#
#    Reporting District  Crime Code  \
# 0                1535         420
# 1                 774         510
#
#                             Crime Code Description MO Codes  \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)     0344
# 1                                 VEHICLE - STOLEN      NaN
#
#           ...          Status Code Status Description Crime Code 1  \
# 0         ...                   IC        Invest Cont          420
# 1         ...                   AA       Adult Arrest          510
#
#    Crime Code 2 Crime Code 3  Crime Code 4  \
# 0           NaN          NaN           NaN
# 1           NaN          NaN           NaN
#
#                                   Address Cross Street             Location   \
# 0                                 TUJUNGA     HATTERAS   (34.1758, -118.379)
# 1  400 S  CROCKER                      ST          NaN  (34.0431, -118.3482)
#
#        Location_clean
# 0   34.1758, -118.379
# 1  34.0431, -118.3482
#
# [2 rows x 27 columns]

# %%
## https://chrisalbon.com/python/data_wrangling/pandas_split_lat_and_long_into_variables/
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in la_crime_df['Location_clean']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        lat.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        lon.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
la_crime_df['Latitude'] = lat
la_crime_df['Longitude'] = lon

# %%
la_crime_df.head(2)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191504131    01/03/2019    01/02/2018           2330       15  N Hollywood
# 1  190704048    01/02/2019    01/02/2018           1000        7     Wilshire
#
#    Reporting District  Crime Code  \
# 0                1535         420
# 1                 774         510
#
#                             Crime Code Description MO Codes     ...      \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)     0344     ...
# 1                                 VEHICLE - STOLEN      NaN     ...
#
#    Crime Code 1 Crime Code 2 Crime Code 3  Crime Code 4  \
# 0           420          NaN          NaN           NaN
# 1           510          NaN          NaN           NaN
#
#                                   Address  Cross Street             Location   \
# 0                                 TUJUNGA      HATTERAS   (34.1758, -118.379)
# 1  400 S  CROCKER                      ST           NaN  (34.0431, -118.3482)
#
#        Location_clean Latitude   Longitude
# 0   34.1758, -118.379  34.1758    -118.379
# 1  34.0431, -118.3482  34.0431   -118.3482
#
# [2 rows x 29 columns]

# %%
print(f"LA Crime number of rows = {la_crime_df['DR Number'].count()}")
# Out:
# LA Crime number of rows = 7918

# %%
# Strip parentheses from column
la_crime_df['Location_clean']=la_crime_df['Location '].str.strip('()')
la_crime_df.head(2)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191504131    01/03/2019    01/02/2018           2330       15  N Hollywood
# 1  190704048    01/02/2019    01/02/2018           1000        7     Wilshire
#
#    Reporting District  Crime Code  \
# 0                1535         420
# 1                 774         510
#
#                             Crime Code Description MO Codes     ...      \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)     0344     ...
# 1                                 VEHICLE - STOLEN      NaN     ...
#
#    Crime Code 1 Crime Code 2 Crime Code 3  Crime Code 4  \
# 0           420          NaN          NaN           NaN
# 1           510          NaN          NaN           NaN
#
#                                   Address  Cross Street             Location   \
# 0                                 TUJUNGA      HATTERAS   (34.1758, -118.379)
# 1  400 S  CROCKER                      ST           NaN  (34.0431, -118.3482)
#
#        Location_clean Latitude   Longitude
# 0   34.1758, -118.379  34.1758    -118.379
# 1  34.0431, -118.3482  34.0431   -118.3482
#
# [2 rows x 29 columns]

# %%
# Separate Date column by day, month and year and the complete date without the hours

# %%
la_crime_df['Year'] = [i[8:10] for i in la_crime_df['Date Reported']]

# %%
la_crime_df['Month'] = [i[3:5] for i in la_crime_df['Date Reported']]

# %%
la_crime_df['Day'] = [i[0:2] for i in la_crime_df['Date Reported']]

# %%
la_crime_df['Parking_Date'] = [i[0:10] for i in la_crime_df['Date Reported']]

# %%
la_crime_df.head(2)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191504131    01/03/2019    01/02/2018           2330       15  N Hollywood
# 1  190704048    01/02/2019    01/02/2018           1000        7     Wilshire
#
#    Reporting District  Crime Code  \
# 0                1535         420
# 1                 774         510
#
#                             Crime Code Description MO Codes      ...       \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)     0344      ...
# 1                                 VEHICLE - STOLEN      NaN      ...
#
#                                   Address Cross Street             Location   \
# 0                                 TUJUNGA     HATTERAS   (34.1758, -118.379)
# 1  400 S  CROCKER                      ST          NaN  (34.0431, -118.3482)
#
#        Location_clean Latitude   Longitude Year Month Day  Parking_Date
# 0   34.1758, -118.379  34.1758    -118.379   19    03  01    01/03/2019
# 1  34.0431, -118.3482  34.0431   -118.3482   19    02  01    01/02/2019
#
# [2 rows x 33 columns]

# %%
la_crime_df.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location ',
#        'Location_clean', 'Latitude', 'Longitude', 'Year', 'Month', 'Day',
#        'Parking_Date'],
#       dtype='object')

# %%
# select columns to use for the project
la_crime_df_new = la_crime_df[['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
       'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
       'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
       'Victim Descent', 'Premise Code', 'Premise Description',
       'Weapon Used Code', 'Weapon Description', 'Status Code',
       'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
       'Crime Code 4', 'Address', 'Cross Street','Location_clean', 'Latitude', 'Longitude', 'Year', 'Month', 'Day',
       'Parking_Date']]

# %%
la_crime_df_new.head(2)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191504131    01/03/2019    01/02/2018           2330       15  N Hollywood
# 1  190704048    01/02/2019    01/02/2018           1000        7     Wilshire
#
#    Reporting District  Crime Code  \
# 0                1535         420
# 1                 774         510
#
#                             Crime Code Description MO Codes      ...       \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)     0344      ...
# 1                                 VEHICLE - STOLEN      NaN      ...
#
#    Crime Code 4                                 Address Cross Street  \
# 0           NaN                                 TUJUNGA     HATTERAS
# 1           NaN  400 S  CROCKER                      ST          NaN
#
#        Location_clean Latitude   Longitude Year Month Day  Parking_Date
# 0   34.1758, -118.379  34.1758    -118.379   19    03  01    01/03/2019
# 1  34.0431, -118.3482  34.0431   -118.3482   19    02  01    01/02/2019
#
# [2 rows x 32 columns]

# %%
# save df to a csv file
la_crime_df_new.to_csv(r'Resources\la_crime_df_new.csv')

# %% [markdown]
# ### Connect to local database

# %%
# Connect to local database
rds_connection_string = "root:modelobootcamp@127.0.0.1/ladata_db"
engine = create_engine(f'mysql://{rds_connection_string}')
connection = engine.connect()

# %%
connection.execute('use ladata_db;')

# %%
engine.table_names()
# Out:
# ['la_parking_df_project']

# %%
la_crime_df_new.to_sql(name='la_crime_df_project', con=engine, if_exists='replace', index=False)

# %%
results = engine.execute('select * from la_crime_df_project;')

# %% [markdown]
# ### Confirm data has been added by querying the la_parking_df table

# %%
connection.execute('use ladata_db;')

# %%
pd.read_sql_query('select * from la_crime_df_project', con=engine).head(2)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191504131    01/03/2019    01/02/2018           2330       15  N Hollywood
# 1  190704048    01/02/2019    01/02/2018           1000        7     Wilshire
#
#    Reporting District  Crime Code  \
# 0                1535         420
# 1                 774         510
#
#                             Crime Code Description MO Codes      ...       \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)     0344      ...
# 1                                 VEHICLE - STOLEN     None      ...
#
#    Crime Code 4                                 Address Cross Street  \
# 0           NaN                                 TUJUNGA     HATTERAS
# 1           NaN  400 S  CROCKER                      ST         None
#
#        Location_clean Latitude   Longitude Year Month Day  Parking_Date
# 0   34.1758, -118.379  34.1758    -118.379   19    03  01    01/03/2019
# 1  34.0431, -118.3482  34.0431   -118.3482   19    02  01    01/02/2019
#
# [2 rows x 32 columns]
