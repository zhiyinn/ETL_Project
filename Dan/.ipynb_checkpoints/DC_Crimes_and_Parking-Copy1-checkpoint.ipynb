# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
csv_file = "Resources/Parking_Violations_DC_2018.csv"
dcparking_df = pd.read_csv(csv_file)
dcparking_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,1,2,3,4,5,6,7,8,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          X        Y OBJECTID ROWID_ DAY_OF_WEEK HOLIDAY WEEK_OF_YEAR  \
# 0 -76.9932  38.8876  4203048    NaN         NaN     NaN          NaN
# 1 -77.0189  38.8967  4203049    NaN         NaN     NaN          NaN
# 2 -77.0109  38.9072  4203050    NaN         NaN     NaN          NaN
# 3 -77.0786  38.9127  4203051    NaN         NaN     NaN          NaN
# 4 -77.0418  38.9233  4203052    NaN         NaN     NaN          NaN
#
#   MONTH_OF_YEAR ISSUE_TIME VIOLATION_CODE  \
# 0           NaN        NaN           P173
# 1           NaN        NaN           P259
# 2           NaN        NaN           P173
# 3           NaN        NaN           P198
# 4           NaN        NaN           P281
#
# ...

# %%
print(dcparking_df.dtypes, sep='\n\n')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,1,2,3,4,5,6,7,8,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# X                        object
# Y                        object
# OBJECTID                 object
# ROWID_                   object
# DAY_OF_WEEK              object
# HOLIDAY                  object
# WEEK_OF_YEAR             object
# MONTH_OF_YEAR            object
# ISSUE_TIME               object
# VIOLATION_CODE           object
# VIOLATION_DESCRIPTION    object
# LOCATION                 object
# RP_PLATE_STATE           object
# BODY_STYLE               object
# ADDRESS_ID               object
# STREETSEGID              object
# XCOORD                   object
# YCOORD                   object
# TICKET_ISSUE_DATE        object
# dtype: object

# %%
new_dcparking_df = dcparking_df[['X','Y','VIOLATION_DESCRIPTION', 'TICKET_ISSUE_DATE' ]].copy()
new_dcparking_df.head()
# Out:
#          X        Y                         VIOLATION_DESCRIPTION  \
# 0 -76.9932  38.8876                    NO PARKING STREET CLEANING
# 1 -77.0189  38.8967  NO STOPPING OR STANDING IN PM RUSH HOUR ZONE
# 2 -77.0109  38.9072                    NO PARKING STREET CLEANING
# 3 -77.0786  38.9127     PARK WITHIN 20 FEET OF A BUS STOP OR ZONE
# 4 -77.0418  38.9233    FAIL TO DISPLAY A MULTISPACE METER RECEIPT
#
#           TICKET_ISSUE_DATE
# 0  2018-04-04T00:00:00.000Z
# 1  2018-04-04T16:08:00.000Z
# 2  2018-04-04T10:04:00.000Z
# 3  2018-04-04T16:31:00.000Z
# 4  2018-04-04T19:22:00.000Z

# %%
csv_file = "Resources/2018 dc-crimes.csv"
dccrimes_df = pd.read_csv(csv_file)
dccrimes_df.head()
# Out:
#   NEIGHBORHOOD_CLUSTER  CENSUS_TRACT offensegroup  LONGITUDE  \
# 0           cluster 20        9501.0      violent -77.001338
# 1            cluster 6       10700.0     property -77.041679
# 2            cluster 8        5800.0     property -77.022434
# 3            cluster 1        3800.0     property -77.040613
# 4            cluster 8        5201.0     property -77.031567
#
#                   END_DATE                offense-text     SHIFT    YBLOCK  \
# 0  2018-06-29T04:16:58.000  assault w/dangerous weapon  midnight  141428.0
# 1  2018-06-29T03:27:13.000                theft f/auto  midnight  137809.0
# 2  2018-06-29T02:58:41.000                    burglary       day  137002.0
# 3  2018-06-16T18:27:19.000                 theft/other  midnight  139054.0
# 4                      NaN                 theft/other   evening  137555.0
#
#    DISTRICT  WARD    ...                                         BLOCK  \
# 0       4.0     5    ...           290 - 399 block of taylor street ne
# ...

# %%
print(dccrimes_df.dtypes, sep='\n\n')
# Out:
# NEIGHBORHOOD_CLUSTER     object
# CENSUS_TRACT            float64
# offensegroup             object
# LONGITUDE               float64
# END_DATE                 object
# offense-text             object
# SHIFT                    object
# YBLOCK                  float64
# DISTRICT                float64
# WARD                      int64
# YEAR                      int64
# offensekey               object
# BID                      object
# sector                   object
# PSA                     float64
# ucr-rank                  int64
# BLOCK_GROUP              object
# VOTING_PRECINCT          object
# XBLOCK                  float64
# BLOCK                    object
# START_DATE               object
# CCN                       int64
# OFFENSE                  object
# OCTO_RECORD_ID           object
# ANC                      object
# REPORT_DAT               object
# METHOD                   object
# location                 object
# LATITUDE                float64
# ...

# %%
new_dccrimes_df = dccrimes_df[['LONGITUDE','LATITUDE','OFFENSE','REPORT_DAT']].copy()
new_dccrimes_df.head()
# Out:
#    LONGITUDE   LATITUDE                     OFFENSE                REPORT_DAT
# 0 -77.001338  38.940742  assault w/dangerous weapon  2018-06-29T07:24:04.000Z
# 1 -77.041679  38.908133                theft f/auto  2018-06-29T07:28:14.000Z
# 2 -77.022434  38.900869                    burglary  2018-06-29T11:20:16.000Z
# 3 -77.040613  38.919349                 theft/other  2018-06-17T05:55:09.000Z
# 4 -77.031567  38.905848                 theft/other  2018-07-03T23:19:56.000Z

# %%
engine = create_engine("mysql://root:Password@localhost/DCDATA_DB")

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#
# ...
